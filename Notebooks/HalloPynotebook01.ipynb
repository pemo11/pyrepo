# %%
import matplotlib.pyplot as plt
d = {"ES":80000,"S":700000, "PL":45000, "NT":33000}
plt.bar(range(len(d)), list(d.values()),align='center')
plt.xticks(range(len(d)), list(d.keys()))
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas
pandas.DataFrame(d, index=['einwohner']).plot(kind='bar')
plt.show()
